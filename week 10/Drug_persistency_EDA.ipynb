# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# to show all the columns of the dataframe in the notebook
pd.set_option('display.max_columns', None)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Importing libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# Loading dataset

# %%
df = pd.read_excel('/content/drive/MyDrive/Healthcare_dataset.xlsx', sheet_name='Dataset')

df.head()
# Out:
#   Ptid Persistency_Flag  Gender           Race     Ethnicity   Region  \
# 0   P1       Persistent    Male      Caucasian  Not Hispanic     West
# 1   P2   Non-Persistent    Male          Asian  Not Hispanic     West
# 2   P3   Non-Persistent  Female  Other/Unknown      Hispanic  Midwest
# 3   P4   Non-Persistent  Female      Caucasian  Not Hispanic  Midwest
# 4   P5   Non-Persistent  Female      Caucasian  Not Hispanic  Midwest
#
#   Age_Bucket        Ntm_Speciality Ntm_Specialist_Flag  \
# 0        >75  GENERAL PRACTITIONER              Others
# 1      55-65  GENERAL PRACTITIONER              Others
# 2      65-75  GENERAL PRACTITIONER              Others
# 3        >75  GENERAL PRACTITIONER              Others
# 4        >75  GENERAL PRACTITIONER              Others
#
#        Ntm_Speciality_Bucket Gluco_Record_Prior_Ntm Gluco_Record_During_Rx  \
# 0  OB/GYN/Others/PCP/Unknown                      N                      N
# 1  OB/GYN/Others/PCP/Unknown                      N                      N
# 2  OB/GYN/Others/PCP/Unknown                      N                      N
# 3  OB/GYN/Others/PCP/Unknown                      N                      Y
# 4  OB/GYN/Others/PCP/Unknown                      Y                      Y
#
#    Dexa_Freq_During_Rx Dexa_During_Rx Frag_Frac_Prior_Ntm Frag_Frac_During_Rx  \
# 0                    0              N                   N                   N
# 1                    0              N                   N                   N
# 2                    0              N                   N                   N
# 3                    0              N                   N                   N
# 4                    0              N                   N                   N
#
#   Risk_Segment_Prior_Ntm Tscore_Bucket_Prior_Ntm Risk_Segment_During_Rx  \
# 0                 VLR_LR                   >-2.5                 VLR_LR
# 1                 VLR_LR                   >-2.5                Unknown
# 2                 HR_VHR                  <=-2.5                 HR_VHR
# 3                 HR_VHR                   >-2.5                 HR_VHR
# 4                 HR_VHR                  <=-2.5                Unknown
#
#   Tscore_Bucket_During_Rx Change_T_Score Change_Risk_Segment Adherent_Flag  \
# 0                  <=-2.5      No change             Unknown      Adherent
# 1                 Unknown        Unknown             Unknown      Adherent
# 2                  <=-2.5      No change           No change      Adherent
# 3                  <=-2.5      No change           No change      Adherent
# 4                 Unknown        Unknown             Unknown      Adherent
#
#   Idn_Indicator Injectable_Experience_During_Rx  \
# 0             N                               Y
# 1             N                               Y
# 2             N                               Y
# 3             N                               Y
# 4             N                               Y
#
#   Comorb_Encounter_For_Screening_For_Malignant_Neoplasms  \
# 0                                                  N
# 1                                                  N
# 2                                                  Y
# 3                                                  N
# 4                                                  Y
#
#   Comorb_Encounter_For_Immunization  \
# 0                                 Y
# 1                                 N
# 2                                 N
# 3                                 Y
# 4                                 Y
#
#   Comorb_Encntr_For_General_Exam_W_O_Complaint,_Susp_Or_Reprtd_Dx  \
# 0                                                  Y
# 1                                                  Y
# 2                                                  Y
# 3                                                  Y
# 4                                                  Y
#
#   Comorb_Vitamin_D_Deficiency  \
# 0                           N
# 1                           N
# 2                           N
# 3                           N
# 4                           N
#
#   Comorb_Other_Joint_Disorder_Not_Elsewhere_Classified  \
# 0                                                  N
# 1                                                  N
# 2                                                  N
# 3                                                  Y
# 4                                                  N
#
#   Comorb_Encntr_For_Oth_Sp_Exam_W_O_Complaint_Suspected_Or_Reprtd_Dx  \
# 0                                                  Y
# 1                                                  N
# 2                                                  N
# 3                                                  N
# 4                                                  N
#
#   Comorb_Long_Term_Current_Drug_Therapy Comorb_Dorsalgia  \
# 0                                     N                Y
# 1                                     N                N
# 2                                     N                N
# 3                                     N                Y
# 4                                     N                Y
#
#   Comorb_Personal_History_Of_Other_Diseases_And_Conditions  \
# 0                                                  Y
# 1                                                  N
# 2                                                  N
# 3                                                  N
# 4                                                  Y
#
#   Comorb_Other_Disorders_Of_Bone_Density_And_Structure  \
# 0                                                  N
# 1                                                  N
# 2                                                  N
# 3                                                  N
# 4                                                  N
#
#   Comorb_Disorders_of_lipoprotein_metabolism_and_other_lipidemias  \
# 0                                                  N
# 1                                                  N
# 2                                                  N
# 3                                                  Y
# 4                                                  N
#
#   Comorb_Osteoporosis_without_current_pathological_fracture  \
# 0                                                  N
# 1                                                  N
# 2                                                  N
# 3                                                  N
# 4                                                  N
#
#   Comorb_Personal_history_of_malignant_neoplasm  \
# 0                                             N
# 1                                             N
# 2                                             N
# 3                                             N
# 4                                             N
#
#   Comorb_Gastro_esophageal_reflux_disease  \
# 0                                       N
# 1                                       N
# 2                                       N
# 3                                       Y
# 4                                       N
#
#   Concom_Cholesterol_And_Triglyceride_Regulating_Preparations  \
# 0                                                  N
# 1                                                  N
# 2                                                  Y
# 3                                                  N
# 4                                                  N
#
#   Concom_Narcotics Concom_Systemic_Corticosteroids_Plain  \
# 0                N                                     N
# 1                N                                     N
# 2                N                                     N
# 3                Y                                     Y
# 4                Y                                     Y
#
#   Concom_Anti_Depressants_And_Mood_Stabilisers Concom_Fluoroquinolones  \
# 0                                            N                       N
# 1                                            N                       N
# 2                                            N                       N
# 3                                            N                       N
# 4                                            Y                       N
#
#   Concom_Cephalosporins Concom_Macrolides_And_Similar_Types  \
# 0                     N                                   N
# 1                     N                                   N
# 2                     N                                   N
# 3                     N                                   N
# 4                     N                                   N
#
#   Concom_Broad_Spectrum_Penicillins Concom_Anaesthetics_General  \
# 0                                 N                           N
# 1                                 N                           N
# 2                                 N                           N
# 3                                 N                           N
# 4                                 N                           N
#
#   Concom_Viral_Vaccines Risk_Type_1_Insulin_Dependent_Diabetes  \
# 0                     N                                      N
# 1                     N                                      N
# 2                     N                                      N
# 3                     Y                                      N
# 4                     N                                      N
#
#   Risk_Osteogenesis_Imperfecta Risk_Rheumatoid_Arthritis  \
# 0                            N                         N
# 1                            N                         N
# 2                            N                         N
# 3                            N                         N
# 4                            N                         N
#
#   Risk_Untreated_Chronic_Hyperthyroidism Risk_Untreated_Chronic_Hypogonadism  \
# 0                                      N                                   N
# 1                                      N                                   N
# 2                                      N                                   N
# 3                                      N                                   N
# 4                                      N                                   N
#
#   Risk_Untreated_Early_Menopause Risk_Patient_Parent_Fractured_Their_Hip  \
# 0                              N                                       N
# 1                              N                                       N
# 2                              N                                       Y
# 3                              N                                       N
# 4                              N                                       N
#
#   Risk_Smoking_Tobacco Risk_Chronic_Malnutrition_Or_Malabsorption  \
# 0                    N                                          N
# 1                    N                                          N
# 2                    N                                          N
# 3                    Y                                          N
# 4                    Y                                          N
#
#   Risk_Chronic_Liver_Disease Risk_Family_History_Of_Osteoporosis  \
# 0                          N                                   N
# 1                          N                                   N
# 2                          N                                   N
# 3                          N                                   N
# 4                          N                                   N
#
#   Risk_Low_Calcium_Intake Risk_Vitamin_D_Insufficiency  \
# 0                       N                            N
# 1                       N                            N
# 2                       Y                            N
# 3                       N                            N
# 4                       N                            N
#
#   Risk_Poor_Health_Frailty Risk_Excessive_Thinness  \
# 0                        N                       N
# 1                        N                       N
# 2                        N                       N
# 3                        N                       N
# 4                        N                       N
#
#   Risk_Hysterectomy_Oophorectomy Risk_Estrogen_Deficiency Risk_Immobilization  \
# 0                              N                        N                   N
# 1                              N                        N                   N
# 2                              N                        N                   N
# 3                              N                        N                   N
# 4                              N                        N                   N
#
#   Risk_Recurring_Falls  Count_Of_Risks
# 0                    N               0
# 1                    N               0
# 2                    N               2
# 3                    N               1
# 4                    N               1

# %%
# dataframe shape
print(df.shape)
# checking for duplicates
print(df.Ptid.unique().shape)
# Out:
# (3424, 69)
# (3424,)

# %%
#creating categorical column list
cat_cols = list(df.select_dtypes(['object']).columns)
print(len(cat_cols))
# Out:
# 67

# %%
#creating column of numerical columns
num_cols = list(df.select_dtypes(['int64']).columns)
print(len(num_cols))
num_cols
# Out:
# 2
# ['Dexa_Freq_During_Rx', 'Count_Of_Risks']

# %% [markdown]
# Checking for missing values

# %%
ax = df.isna().sum().sort_values().plot(kind = 'barh', figsize = (9, 10))
plt.title('Percentage of Missing Values Per Column in Train Set', fontdict={'size':15})
for p in ax.patches:
    percentage ='{:,.0f}%'.format((p.get_width()/df.shape[0])*100)
    width, height =p.get_width(),p.get_height()
    x=p.get_x()+width+0.02
    y=p.get_y()+height/2
    ax.annotate(percentage,(x,y))

# %%
corr = df.corr()

# %%
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(400, 3000, n=400),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);

# %%
# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)
#cmap = sns.diverging_palette(20, 220, n=400)

# Draw the heatmap with the mask and correct aspect ratio
ax = sns.heatmap(corr, mask=mask, cmap=cmap, vmax=1, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .7})
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);

# %%
import matplotlib.ticker as ticker

# %%
t = pd.DataFrame(data={"col": df.dtypes.index, "type": df.dtypes}).reset_index(drop=True)
col_names = t["col"][t.type != "object"]
col_names
# Out:
# 12            Dexa_Freq_During_Rx
# 68                 Count_Of_Risks
# 69    min_max_Dexa_Freq_During_Rx
# 70         min_max_Count_Of_Risks
# 71       sqrt_Dexa_Freq_During_Rx
# 72            sqrt_Count_Of_Risks
# 73                          dummy
# Name: col, dtype: object

# %%
#bar graph for value counts for categorical columns
def plot_catcols(x, df):
    df['dummy'] = np.ones(shape = df.shape[0])
    for col in x:
        print(col)
        counts = df[['dummy', col]].groupby([col], as_index = False).count()
        fig, ax = plt.subplots(figsize = (10,4))
        graph = plt.barh(counts[col], counts.dummy) #creating a graph
        plt.xticks(rotation=90)
        plt.title('Counts for ' + col)
        plt.xlabel('count')
        #getting percentages
        total = counts['dummy'].sum()
        percentage = []
        for i in range(counts.shape[0]):
            pct = (counts.dummy[i]/total)*100
            percentage.append(round(pct, 2))
        counts['Percentage'] = percentage
        # plotting the graph with percentages
        i = 0
        for p in graph:
            pct = f'{percentage[i]}%'
            width1, height1 =p.get_width(),p.get_height()
            x1 =p.get_x()+width1
            y1=p.get_y()+height1/2
            ax.annotate(pct,(x1,y1))
            i+=1
        plt.show()
plot_catcols(cat_cols, df)
# Out:
# Ptid
# Persistency_Flag
# Gender
# Race
# Ethnicity
# Region
# Age_Bucket
# Ntm_Speciality
# Ntm_Specialist_Flag
# Ntm_Speciality_Bucket
# Gluco_Record_Prior_Ntm
# Gluco_Record_During_Rx
# Dexa_During_Rx
# Frag_Frac_Prior_Ntm
# Frag_Frac_During_Rx
# Risk_Segment_Prior_Ntm
# Tscore_Bucket_Prior_Ntm
# Risk_Segment_During_Rx
# Tscore_Bucket_During_Rx
# Change_T_Score
# Change_Risk_Segment
# Adherent_Flag
# Idn_Indicator
# Injectable_Experience_During_Rx
# Comorb_Encounter_For_Screening_For_Malignant_Neoplasms
# Comorb_Encounter_For_Immunization
# Comorb_Encntr_For_General_Exam_W_O_Complaint,_Susp_Or_Reprtd_Dx
# Comorb_Vitamin_D_Deficiency
# Comorb_Other_Joint_Disorder_Not_Elsewhere_Classified
# Comorb_Encntr_For_Oth_Sp_Exam_W_O_Complaint_Suspected_Or_Reprtd_Dx
# Comorb_Long_Term_Current_Drug_Therapy
# Comorb_Dorsalgia
# Comorb_Personal_History_Of_Other_Diseases_And_Conditions
# Comorb_Other_Disorders_Of_Bone_Density_And_Structure
# Comorb_Disorders_of_lipoprotein_metabolism_and_other_lipidemias
# Comorb_Osteoporosis_without_current_pathological_fracture
# Comorb_Personal_history_of_malignant_neoplasm
# Comorb_Gastro_esophageal_reflux_disease
# Concom_Cholesterol_And_Triglyceride_Regulating_Preparations
# Concom_Narcotics
# Concom_Systemic_Corticosteroids_Plain
# Concom_Anti_Depressants_And_Mood_Stabilisers
# Concom_Fluoroquinolones
# Concom_Cephalosporins
# Concom_Macrolides_And_Similar_Types
# Concom_Broad_Spectrum_Penicillins
# Concom_Anaesthetics_General
# Concom_Viral_Vaccines
# Risk_Type_1_Insulin_Dependent_Diabetes
# Risk_Osteogenesis_Imperfecta
# Risk_Rheumatoid_Arthritis
# Risk_Untreated_Chronic_Hyperthyroidism
# Risk_Untreated_Chronic_Hypogonadism
# Risk_Untreated_Early_Menopause
# Risk_Patient_Parent_Fractured_Their_Hip
# Risk_Smoking_Tobacco
# Risk_Chronic_Malnutrition_Or_Malabsorption
# Risk_Chronic_Liver_Disease
# Risk_Family_History_Of_Osteoporosis
# Risk_Low_Calcium_Intake
# Risk_Vitamin_D_Insufficiency
# Risk_Poor_Health_Frailty
# Risk_Excessive_Thinness
# Risk_Hysterectomy_Oophorectomy
# Risk_Estrogen_Deficiency
# Risk_Immobilization
# Risk_Recurring_Falls

# %% [markdown]
# **Outlier Identification and Treatment**

# %% [markdown]
# 1. Identifying and treating using Boolean method

# %%
#making copy of dataset
df2=df.copy()

# %% [markdown]
# For column Dexa_Freq_During_Rx

# %%
#for Dexa frequency during RX, find IQR
Q1 = df2['Dexa_Freq_During_Rx'].quantile(0.25)
Q3 = df2['Dexa_Freq_During_Rx'].quantile(0.75)
IQR=Q3-Q1
IQR
# Out:
# 3.0

# %%
#create a Boolean mask that sums up the number of possible outliers in column using the IQR above.
mask_high = (df2['Dexa_Freq_During_Rx'] > (Q3 + 1.5 * IQR))
mask_high
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3419    False
# 3420    False
# 3421    False
# 3422    False
# 3423    False
# Name: Dexa_Freq_During_Rx, Length: 3424, dtype: bool

# %%
mask_high.sum() #number of outliers for dexa_freq_during_rx
# Out:
# 460

# %%
#find and change the values of the high outliers,this is call capping 
df2.Dexa_Freq_During_Rx[mask_high]
# Out:
# 32      20
# 33      13
# 62      12
# 65      20
# 89      10
#         ..
# 3384    12
# 3396    10
# 3400    12
# 3411     8
# 3414     8
# Name: Dexa_Freq_During_Rx, Length: 460, dtype: int64

# %% [markdown]
# For column Count_Of_Risks

# %%
#for Count_Of_Risks, find IQR
Q1 = df2['Count_Of_Risks'].quantile(0.25)
Q3 = df2['Count_Of_Risks'].quantile(0.75)
IQR=Q3-Q1
IQR
# Out:
# 2.0

# %%
#create a Boolean mask that sums up the number of possible outliers in column using the IQR above.
mask_high = (df2['Count_Of_Risks'] > (Q3 + 1.5 * IQR))
mask_high
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3419    False
# 3420    False
# 3421    False
# 3422    False
# 3423    False
# Name: Count_Of_Risks, Length: 3424, dtype: bool

# %%
mask_high.sum() #number of outliers for count_of_risks
# Out:
# 8

# %%
##find and change the values of the high outliers,this is call capping 
df2.Count_Of_Risks[mask_high]
# Out:
# 342     6
# 817     7
# 1059    7
# 2601    6
# 2860    6
# 3045    6
# 3146    6
# 3340    6
# Name: Count_Of_Risks, dtype: int64

# %% [markdown]
# 2. Identifying outliers using  boxplots

# %%
# creating a box plot of numerical columns to identify outliers
def boxplot(df, cols):
    for col in cols:
        sns.set_style('whitegrid')
        sns.boxplot(y=col, data=df)
        plt.title('Boxplot of ' + col)
        plt.ylabel(col) #setting text for y axis
        plt.show()
boxplot(df, num_cols)

# %% [markdown]
# 3. Identifying and treating outliers using Z-score

# %% [markdown]
# For column Dexa_Freq_During_Rx

# %%
df1=df.copy() #getting a copy of dataset

# %%
#finding the boundary values for Dexa_freq_during_rx
high=df1['Dexa_Freq_During_Rx'].mean() + 3*df1['Dexa_Freq_During_Rx'].std()
low=df1['Dexa_Freq_During_Rx'].mean() - 3*df1['Dexa_Freq_During_Rx'].std()

# %%
print("Highest allowed",high)
print("Lowest allowed",low)
# Out:
# Highest allowed 27.425698069039147
# Lowest allowed -21.393571900814845

# %%
#finding outliers
newdf=df1[(df1['Dexa_Freq_During_Rx'] > high) | (df1['Dexa_Freq_During_Rx'] < low)]
newdf.head()
# Out:
#        Ptid Persistency_Flag  Gender       Race     Ethnicity   Region  \
# 198    P199       Persistent  Female  Caucasian  Not Hispanic    South
# 241    P242       Persistent  Female  Caucasian  Not Hispanic  Midwest
# 541    P542       Persistent  Female  Caucasian  Not Hispanic  Midwest
# 651    P652       Persistent  Female  Caucasian  Not Hispanic  Midwest
# 1265  P1266       Persistent  Female  Caucasian  Not Hispanic     West
#
#      Age_Bucket        Ntm_Speciality Ntm_Specialist_Flag  \
# 198         >75         ENDOCRINOLOGY          Specialist
# 241         >75  GENERAL PRACTITIONER              Others
# 541       65-75  GENERAL PRACTITIONER              Others
# 651       65-75            PEDIATRICS              Others
# 1265        >75         ENDOCRINOLOGY          Specialist
#
#           Ntm_Speciality_Bucket Gluco_Record_Prior_Ntm Gluco_Record_During_Rx  \
# 198                Endo/Onc/Uro                      N                      Y
# 241   OB/GYN/Others/PCP/Unknown                      N                      Y
# 541   OB/GYN/Others/PCP/Unknown                      N                      N
# 651   OB/GYN/Others/PCP/Unknown                      Y                      Y
# 1265               Endo/Onc/Uro                      N                      N
#
#       Dexa_Freq_During_Rx Dexa_During_Rx Frag_Frac_Prior_Ntm  \
# 198                    28              Y                   N
# 241                    37              Y                   N
# 541                    81              Y                   Y
# 651                    42              Y                   N
# 1265                   28              Y                   N
#
#      Frag_Frac_During_Rx Risk_Segment_Prior_Ntm Tscore_Bucket_Prior_Ntm  \
# 198                    Y                 VLR_LR                   >-2.5
# 241                    N                 VLR_LR                   >-2.5
# 541                    N                 VLR_LR                   >-2.5
# 651                    N                 HR_VHR                  <=-2.5
# 1265                   N                 HR_VHR                  <=-2.5
#
#      Risk_Segment_During_Rx Tscore_Bucket_During_Rx Change_T_Score  \
# 198                  HR_VHR                  <=-2.5       Worsened
# 241                 Unknown                 Unknown        Unknown
# 541                  HR_VHR                  <=-2.5       Worsened
# 651                  HR_VHR                  <=-2.5      No change
# 1265                 HR_VHR                  <=-2.5       Improved
#
#      Change_Risk_Segment Adherent_Flag Idn_Indicator  \
# 198             Worsened      Adherent             Y
# 241              Unknown      Adherent             Y
# 541              Unknown      Adherent             Y
# 651            No change      Adherent             Y
# 1265           No change      Adherent             Y
#
#      Injectable_Experience_During_Rx  \
# 198                                Y
# 241                                Y
# 541                                Y
# 651                                Y
# 1265                               Y
#
#      Comorb_Encounter_For_Screening_For_Malignant_Neoplasms  \
# 198                                                   N
# 241                                                   N
# 541                                                   Y
# 651                                                   Y
# 1265                                                  Y
#
#      Comorb_Encounter_For_Immunization  \
# 198                                  Y
# 241                                  Y
# 541                                  Y
# 651                                  Y
# 1265                                 Y
#
#      Comorb_Encntr_For_General_Exam_W_O_Complaint,_Susp_Or_Reprtd_Dx  \
# 198                                                   Y
# 241                                                   Y
# 541                                                   Y
# 651                                                   N
# 1265                                                  Y
#
#      Comorb_Vitamin_D_Deficiency  \
# 198                            N
# 241                            Y
# 541                            N
# 651                            Y
# 1265                           Y
#
#      Comorb_Other_Joint_Disorder_Not_Elsewhere_Classified  \
# 198                                                   Y
# 241                                                   Y
# 541                                                   N
# 651                                                   N
# 1265                                                  N
#
#      Comorb_Encntr_For_Oth_Sp_Exam_W_O_Complaint_Suspected_Or_Reprtd_Dx  \
# 198                                                   N
# 241                                                   Y
# 541                                                   Y
# 651                                                   N
# 1265                                                  N
#
#      Comorb_Long_Term_Current_Drug_Therapy Comorb_Dorsalgia  \
# 198                                      Y                Y
# 241                                      Y                Y
# 541                                      N                N
# 651                                      N                N
# 1265                                     Y                N
#
#      Comorb_Personal_History_Of_Other_Diseases_And_Conditions  \
# 198                                                   Y
# 241                                                   N
# 541                                                   N
# 651                                                   N
# 1265                                                  N
#
#      Comorb_Other_Disorders_Of_Bone_Density_And_Structure  \
# 198                                                   N
# 241                                                   Y
# 541                                                   N
# 651                                                   N
# 1265                                                  N
#
#      Comorb_Disorders_of_lipoprotein_metabolism_and_other_lipidemias  \
# 198                                                   Y
# 241                                                   Y
# 541                                                   Y
# 651                                                   Y
# 1265                                                  N
#
#      Comorb_Osteoporosis_without_current_pathological_fracture  \
# 198                                                   N
# 241                                                   N
# 541                                                   N
# 651                                                   N
# 1265                                                  N
#
#      Comorb_Personal_history_of_malignant_neoplasm  \
# 198                                              N
# 241                                              Y
# 541                                              Y
# 651                                              N
# 1265                                             Y
#
#      Comorb_Gastro_esophageal_reflux_disease  \
# 198                                        Y
# 241                                        N
# 541                                        N
# 651                                        N
# 1265                                       Y
#
#      Concom_Cholesterol_And_Triglyceride_Regulating_Preparations  \
# 198                                                   N
# 241                                                   N
# 541                                                   Y
# 651                                                   Y
# 1265                                                  Y
#
#      Concom_Narcotics Concom_Systemic_Corticosteroids_Plain  \
# 198                 Y                                     Y
# 241                 N                                     Y
# 541                 N                                     N
# 651                 N                                     Y
# 1265                Y                                     N
#
#      Concom_Anti_Depressants_And_Mood_Stabilisers Concom_Fluoroquinolones  \
# 198                                             N                       Y
# 241                                             Y                       Y
# 541                                             N                       N
# 651                                             N                       N
# 1265                                            Y                       Y
#
#      Concom_Cephalosporins Concom_Macrolides_And_Similar_Types  \
# 198                      Y                                   Y
# 241                      N                                   Y
# 541                      N                                   N
# 651                      Y                                   Y
# 1265                     N                                   N
#
#      Concom_Broad_Spectrum_Penicillins Concom_Anaesthetics_General  \
# 198                                  Y                           N
# 241                                  Y                           N
# 541                                  N                           Y
# 651                                  Y                           N
# 1265                                 N                           N
#
#      Concom_Viral_Vaccines Risk_Type_1_Insulin_Dependent_Diabetes  \
# 198                      N                                      N
# 241                      N                                      N
# 541                      N                                      N
# 651                      Y                                      N
# 1265                     Y                                      N
#
#      Risk_Osteogenesis_Imperfecta Risk_Rheumatoid_Arthritis  \
# 198                             N                         N
# 241                             N                         N
# 541                             N                         N
# 651                             N                         N
# 1265                            N                         N
#
#      Risk_Untreated_Chronic_Hyperthyroidism  \
# 198                                       N
# 241                                       N
# 541                                       N
# 651                                       N
# 1265                                      N
#
#      Risk_Untreated_Chronic_Hypogonadism Risk_Untreated_Early_Menopause  \
# 198                                    N                              N
# 241                                    N                              N
# 541                                    N                              N
# 651                                    N                              N
# 1265                                   N                              N
#
#      Risk_Patient_Parent_Fractured_Their_Hip Risk_Smoking_Tobacco  \
# 198                                        N                    N
# 241                                        N                    N
# 541                                        N                    N
# 651                                        N                    Y
# 1265                                       N                    N
#
#      Risk_Chronic_Malnutrition_Or_Malabsorption Risk_Chronic_Liver_Disease  \
# 198                                           Y                          N
# 241                                           N                          N
# 541                                           N                          N
# 651                                           Y                          N
# 1265                                          N                          N
#
#      Risk_Family_History_Of_Osteoporosis Risk_Low_Calcium_Intake  \
# 198                                    Y                       N
# 241                                    N                       N
# 541                                    N                       N
# 651                                    N                       N
# 1265                                   N                       N
#
#      Risk_Vitamin_D_Insufficiency Risk_Poor_Health_Frailty  \
# 198                             Y                        N
# 241                             Y                        N
# 541                             N                        N
# 651                             Y                        N
# 1265                            Y                        N
#
#      Risk_Excessive_Thinness Risk_Hysterectomy_Oophorectomy  \
# 198                        N                              N
# 241                        N                              N
# 541                        N                              N
# 651                        N                              N
# 1265                       N                              N
#
#      Risk_Estrogen_Deficiency Risk_Immobilization Risk_Recurring_Falls  \
# 198                         N                   N                    N
# 241                         N                   N                    N
# 541                         N                   N                    N
# 651                         N                   N                    N
# 1265                        N                   N                    N
#
#       Count_Of_Risks
# 198                3
# 241                1
# 541                0
# 651                3
# 1265               1

# %%
#treating outliers
#Applying the capping on outliers
df1['Dexa_Freq_During_Rx'] = np.where(
    df1['Dexa_Freq_During_Rx']> high,
    high,
    np.where(
        df1['Dexa_Freq_During_Rx']<low,
        low,
        df1['Dexa_Freq_During_Rx']
    )
)

# %%
#checking outliers after capping
newdf=df1[(df1['Dexa_Freq_During_Rx'] > high) | (df1['Dexa_Freq_During_Rx'] < low)]
newdf.head()
# Out:
# Empty DataFrame
# Columns: [Ptid, Persistency_Flag, Gender, Race, Ethnicity, Region, Age_Bucket, Ntm_Speciality, Ntm_Specialist_Flag, Ntm_Speciality_Bucket, Gluco_Record_Prior_Ntm, Gluco_Record_During_Rx, Dexa_Freq_During_Rx, Dexa_During_Rx, Frag_Frac_Prior_Ntm, Frag_Frac_During_Rx, Risk_Segment_Prior_Ntm, Tscore_Bucket_Prior_Ntm, Risk_Segment_During_Rx, Tscore_Bucket_During_Rx, Change_T_Score, Change_Risk_Segment, Adherent_Flag, Idn_Indicator, Injectable_Experience_During_Rx, Comorb_Encounter_For_Screening_For_Malignant_Neoplasms, Comorb_Encounter_For_Immunization, Comorb_Encntr_For_General_Exam_W_O_Complaint,_Susp_Or_Reprtd_Dx, Comorb_Vitamin_D_Deficiency, Comorb_Other_Joint_Disorder_Not_Elsewhere_Classified, Comorb_Encntr_For_Oth_Sp_Exam_W_O_Complaint_Suspected_Or_Reprtd_Dx, Comorb_Long_Term_Current_Drug_Therapy, Comorb_Dorsalgia, Comorb_Personal_History_Of_Other_Diseases_And_Conditions, Comorb_Other_Disorders_Of_Bone_Density_And_Structure, Comorb_Disorders_of_lipoprotein_metabolism_and_other_lipidemias, Comorb_Osteoporosis_without_current_pathological_fracture, Comorb_Personal_history_of_malignant_neoplasm, Comorb_Gastro_esophageal_reflux_disease, Concom_Cholesterol_And_Triglyceride_Regulating_Preparations, Concom_Narcotics, Concom_Systemic_Corticosteroids_Plain, Concom_Anti_Depressants_And_Mood_Stabilisers, Concom_Fluoroquinolones, Concom_Cephalosporins, Concom_Macrolides_And_Similar_Types, Concom_Broad_Spectrum_Penicillins, Concom_Anaesthetics_General, Concom_Viral_Vaccines, Risk_Type_1_Insulin_Dependent_Diabetes, Risk_Osteogenesis_Imperfecta, Risk_Rheumatoid_Arthritis, Risk_Untreated_Chronic_Hyperthyroidism, Risk_Untreated_Chronic_Hypogonadism, Risk_Untreated_Early_Menopause, Risk_Patient_Parent_Fractured_Their_Hip, Risk_Smoking_Tobacco, Risk_Chronic_Malnutrition_Or_Malabsorption, Risk_Chronic_Liver_Disease, Risk_Family_History_Of_Osteoporosis, Risk_Low_Calcium_Intake, Risk_Vitamin_D_Insufficiency, Risk_Poor_Health_Frailty, Risk_Excessive_Thinness, Risk_Hysterectomy_Oophorectomy, Risk_Estrogen_Deficiency, Risk_Immobilization, Risk_Recurring_Falls, Count_Of_Risks]
# Index: []

# %% [markdown]
# For column Count_Of_Risk

# %%
df1=df.copy() #getting a copy of dataset

# %%
#finding the boundary values 
high=df1['Count_Of_Risks'].mean() + 3*df1['Count_Of_Risks'].std()
low=df1['Count_Of_Risks'].mean() - 3*df1['Count_Of_Risks'].std()

# %%
print("Highest allowed",high)
print("Lowest allowed",low)
# Out:
# Highest allowed 4.52422941524692
# Lowest allowed -2.0452574526300977

# %%
#finding outliers
newdf=df1[(df1['Count_Of_Risks'] > high) | (df1['Count_Of_Risks'] < low)]
newdf.head()
# Out:
#      Ptid Persistency_Flag  Gender       Race     Ethnicity Region Age_Bucket  \
# 302  P303       Persistent  Female  Caucasian  Not Hispanic  South        >75
# 342  P343       Persistent  Female  Caucasian  Not Hispanic  South        >75
# 352  P353       Persistent  Female  Caucasian  Not Hispanic  South        >75
# 495  P496       Persistent  Female  Caucasian  Not Hispanic  South        >75
# 557  P558       Persistent  Female  Caucasian  Not Hispanic  South      65-75
#
#     Ntm_Speciality Ntm_Specialist_Flag      Ntm_Speciality_Bucket  \
# 302        Unknown              Others  OB/GYN/Others/PCP/Unknown
# 342  ENDOCRINOLOGY          Specialist               Endo/Onc/Uro
# 352  ENDOCRINOLOGY          Specialist               Endo/Onc/Uro
# 495  ENDOCRINOLOGY          Specialist               Endo/Onc/Uro
# 557  ENDOCRINOLOGY          Specialist               Endo/Onc/Uro
#
#     Gluco_Record_Prior_Ntm Gluco_Record_During_Rx  Dexa_Freq_During_Rx  \
# 302                      Y                      N                    0
# 342                      N                      Y                    0
# 352                      N                      N                    0
# 495                      Y                      Y                   12
# 557                      Y                      N                    5
#
#     Dexa_During_Rx Frag_Frac_Prior_Ntm Frag_Frac_During_Rx  \
# 302              N                   N                   N
# 342              N                   Y                   N
# 352              N                   N                   N
# 495              Y                   N                   N
# 557              Y                   N                   N
#
#     Risk_Segment_Prior_Ntm Tscore_Bucket_Prior_Ntm Risk_Segment_During_Rx  \
# 302                 VLR_LR                   >-2.5                 VLR_LR
# 342                 HR_VHR                  <=-2.5                 HR_VHR
# 352                 VLR_LR                   >-2.5                 VLR_LR
# 495                 VLR_LR                   >-2.5                 VLR_LR
# 557                 VLR_LR                   >-2.5                 VLR_LR
#
#     Tscore_Bucket_During_Rx Change_T_Score Change_Risk_Segment Adherent_Flag  \
# 302                   >-2.5      No change             Unknown      Adherent
# 342                   >-2.5      No change           No change      Adherent
# 352                   >-2.5      No change             Unknown      Adherent
# 495                   >-2.5      No change             Unknown      Adherent
# 557                   >-2.5      No change           No change      Adherent
#
#     Idn_Indicator Injectable_Experience_During_Rx  \
# 302             Y                               Y
# 342             Y                               Y
# 352             Y                               Y
# 495             Y                               Y
# 557             Y                               Y
#
#     Comorb_Encounter_For_Screening_For_Malignant_Neoplasms  \
# 302                                                  Y
# 342                                                  Y
# 352                                                  Y
# 495                                                  Y
# 557                                                  Y
#
#     Comorb_Encounter_For_Immunization  \
# 302                                 Y
# 342                                 Y
# 352                                 Y
# 495                                 Y
# 557                                 Y
#
#     Comorb_Encntr_For_General_Exam_W_O_Complaint,_Susp_Or_Reprtd_Dx  \
# 302                                                  Y
# 342                                                  N
# 352                                                  Y
# 495                                                  N
# 557                                                  Y
#
#     Comorb_Vitamin_D_Deficiency  \
# 302                           Y
# 342                           Y
# 352                           Y
# 495                           Y
# 557                           Y
#
#     Comorb_Other_Joint_Disorder_Not_Elsewhere_Classified  \
# 302                                                  Y
# 342                                                  Y
# 352                                                  N
# 495                                                  Y
# 557                                                  Y
#
#     Comorb_Encntr_For_Oth_Sp_Exam_W_O_Complaint_Suspected_Or_Reprtd_Dx  \
# 302                                                  N
# 342                                                  N
# 352                                                  N
# 495                                                  N
# 557                                                  N
#
#     Comorb_Long_Term_Current_Drug_Therapy Comorb_Dorsalgia  \
# 302                                     Y                N
# 342                                     N                N
# 352                                     N                N
# 495                                     Y                N
# 557                                     Y                Y
#
#     Comorb_Personal_History_Of_Other_Diseases_And_Conditions  \
# 302                                                  Y
# 342                                                  N
# 352                                                  N
# 495                                                  Y
# 557                                                  Y
#
#     Comorb_Other_Disorders_Of_Bone_Density_And_Structure  \
# 302                                                  N
# 342                                                  N
# 352                                                  Y
# 495                                                  N
# 557                                                  Y
#
#     Comorb_Disorders_of_lipoprotein_metabolism_and_other_lipidemias  \
# 302                                                  Y
# 342                                                  Y
# 352                                                  Y
# 495                                                  Y
# 557                                                  Y
#
#     Comorb_Osteoporosis_without_current_pathological_fracture  \
# 302                                                  N
# 342                                                  N
# 352                                                  Y
# 495                                                  N
# 557                                                  Y
#
#     Comorb_Personal_history_of_malignant_neoplasm  \
# 302                                             N
# 342                                             N
# 352                                             N
# 495                                             N
# 557                                             Y
#
#     Comorb_Gastro_esophageal_reflux_disease  \
# 302                                       N
# 342                                       N
# 352                                       N
# 495                                       Y
# 557                                       N
#
#     Concom_Cholesterol_And_Triglyceride_Regulating_Preparations  \
# 302                                                  Y
# 342                                                  Y
# 352                                                  N
# 495                                                  N
# 557                                                  Y
#
#     Concom_Narcotics Concom_Systemic_Corticosteroids_Plain  \
# 302                Y                                     N
# 342                N                                     Y
# 352                Y                                     Y
# 495                N                                     Y
# 557                Y                                     N
#
#     Concom_Anti_Depressants_And_Mood_Stabilisers Concom_Fluoroquinolones  \
# 302                                            N                       Y
# 342                                            N                       Y
# 352                                            Y                       N
# 495                                            Y                       Y
# 557                                            N                       Y
#
#     Concom_Cephalosporins Concom_Macrolides_And_Similar_Types  \
# 302                     Y                                   N
# 342                     N                                   Y
# 352                     N                                   N
# 495                     N                                   N
# 557                     N                                   Y
#
#     Concom_Broad_Spectrum_Penicillins Concom_Anaesthetics_General  \
# 302                                 Y                           N
# 342                                 N                           N
# 352                                 N                           N
# 495                                 Y                           Y
# 557                                 N                           N
#
#     Concom_Viral_Vaccines Risk_Type_1_Insulin_Dependent_Diabetes  \
# 302                     N                                      N
# 342                     N                                      N
# 352                     N                                      N
# 495                     N                                      N
# 557                     N                                      Y
#
#     Risk_Osteogenesis_Imperfecta Risk_Rheumatoid_Arthritis  \
# 302                            N                         N
# 342                            N                         N
# 352                            N                         N
# 495                            N                         N
# 557                            N                         N
#
#     Risk_Untreated_Chronic_Hyperthyroidism  \
# 302                                      N
# 342                                      N
# 352                                      N
# 495                                      N
# 557                                      N
#
#     Risk_Untreated_Chronic_Hypogonadism Risk_Untreated_Early_Menopause  \
# 302                                   N                              N
# 342                                   Y                              N
# 352                                   Y                              N
# 495                                   Y                              N
# 557                                   N                              N
#
#     Risk_Patient_Parent_Fractured_Their_Hip Risk_Smoking_Tobacco  \
# 302                                       Y                    Y
# 342                                       Y                    Y
# 352                                       Y                    N
# 495                                       Y                    N
# 557                                       Y                    Y
#
#     Risk_Chronic_Malnutrition_Or_Malabsorption Risk_Chronic_Liver_Disease  \
# 302                                          Y                          N
# 342                                          N                          N
# 352                                          N                          N
# 495                                          Y                          N
# 557                                          N                          N
#
#     Risk_Family_History_Of_Osteoporosis Risk_Low_Calcium_Intake  \
# 302                                   Y                       N
# 342                                   Y                       N
# 352                                   Y                       N
# 495                                   Y                       N
# 557                                   N                       N
#
#     Risk_Vitamin_D_Insufficiency Risk_Poor_Health_Frailty  \
# 302                            Y                        N
# 342                            Y                        Y
# 352                            Y                        Y
# 495                            Y                        N
# 557                            Y                        Y
#
#     Risk_Excessive_Thinness Risk_Hysterectomy_Oophorectomy  \
# 302                       N                              N
# 342                       N                              N
# 352                       N                              N
# 495                       N                              N
# 557                       N                              N
#
#     Risk_Estrogen_Deficiency Risk_Immobilization Risk_Recurring_Falls  \
# 302                        N                   N                    N
# 342                        N                   N                    N
# 352                        N                   N                    N
# 495                        N                   N                    N
# 557                        N                   N                    N
#
#      Count_Of_Risks
# 302               5
# 342               6
# 352               5
# 495               5
# 557               5

# %%
#treating outliers
#Applying the capping on outliers
df1['Count_Of_Risks'] = np.where(
    df1['Count_Of_Risks']> high,
    high,
    np.where(
        df1['Count_Of_Risks']<low,
        low,
        df1['Count_Of_Risks']
    )
)

# %%
#checking outliers after capping
newdf=df1[(df1['Count_Of_Risks'] > high) | (df1['Count_Of_Risks'] < low)]
newdf.head()
# Out:
# Empty DataFrame
# Columns: [Ptid, Persistency_Flag, Gender, Race, Ethnicity, Region, Age_Bucket, Ntm_Speciality, Ntm_Specialist_Flag, Ntm_Speciality_Bucket, Gluco_Record_Prior_Ntm, Gluco_Record_During_Rx, Dexa_Freq_During_Rx, Dexa_During_Rx, Frag_Frac_Prior_Ntm, Frag_Frac_During_Rx, Risk_Segment_Prior_Ntm, Tscore_Bucket_Prior_Ntm, Risk_Segment_During_Rx, Tscore_Bucket_During_Rx, Change_T_Score, Change_Risk_Segment, Adherent_Flag, Idn_Indicator, Injectable_Experience_During_Rx, Comorb_Encounter_For_Screening_For_Malignant_Neoplasms, Comorb_Encounter_For_Immunization, Comorb_Encntr_For_General_Exam_W_O_Complaint,_Susp_Or_Reprtd_Dx, Comorb_Vitamin_D_Deficiency, Comorb_Other_Joint_Disorder_Not_Elsewhere_Classified, Comorb_Encntr_For_Oth_Sp_Exam_W_O_Complaint_Suspected_Or_Reprtd_Dx, Comorb_Long_Term_Current_Drug_Therapy, Comorb_Dorsalgia, Comorb_Personal_History_Of_Other_Diseases_And_Conditions, Comorb_Other_Disorders_Of_Bone_Density_And_Structure, Comorb_Disorders_of_lipoprotein_metabolism_and_other_lipidemias, Comorb_Osteoporosis_without_current_pathological_fracture, Comorb_Personal_history_of_malignant_neoplasm, Comorb_Gastro_esophageal_reflux_disease, Concom_Cholesterol_And_Triglyceride_Regulating_Preparations, Concom_Narcotics, Concom_Systemic_Corticosteroids_Plain, Concom_Anti_Depressants_And_Mood_Stabilisers, Concom_Fluoroquinolones, Concom_Cephalosporins, Concom_Macrolides_And_Similar_Types, Concom_Broad_Spectrum_Penicillins, Concom_Anaesthetics_General, Concom_Viral_Vaccines, Risk_Type_1_Insulin_Dependent_Diabetes, Risk_Osteogenesis_Imperfecta, Risk_Rheumatoid_Arthritis, Risk_Untreated_Chronic_Hyperthyroidism, Risk_Untreated_Chronic_Hypogonadism, Risk_Untreated_Early_Menopause, Risk_Patient_Parent_Fractured_Their_Hip, Risk_Smoking_Tobacco, Risk_Chronic_Malnutrition_Or_Malabsorption, Risk_Chronic_Liver_Disease, Risk_Family_History_Of_Osteoporosis, Risk_Low_Calcium_Intake, Risk_Vitamin_D_Insufficiency, Risk_Poor_Health_Frailty, Risk_Excessive_Thinness, Risk_Hysterectomy_Oophorectomy, Risk_Estrogen_Deficiency, Risk_Immobilization, Risk_Recurring_Falls, Count_Of_Risks]
# Index: []

# %% [markdown]
# **Identification of Skewed Data and Treatment**

# %% [markdown]
# **Identification**

# %% [markdown]
# 1. Using histograms

# %%
# ploting histogram for numerical columns
def plot_histogram(df, cols, bins=6):
    for col in cols:
        fig = plt.figure(figsize=(8,8))
        ax= fig.gca()
        df[col].plot.hist(ax = ax, bins = bins, color = 'blue')
        ax.set_title('Histogram of ' + col)
        ax.set_xlabel(col)
        ax.set_ylabel('Number')
        plt.show()
plot_histogram(df, num_cols)

# %% [markdown]
# 2. Getting skewness and kurtosis measurement

# %%
def measure_skew_kurtosis(cols):
    for col in cols:
        print(col)
        result = df[[col]].agg(['skew', 'kurtosis']).transpose()
        print(result)
measure_skew_kurtosis(num_cols)
# Out:
# Dexa_Freq_During_Rx
#                         skew   kurtosis
# Dexa_Freq_During_Rx  6.80873  74.758378
# Count_Of_Risks
#                     skew  kurtosis
# Count_Of_Risks  0.879791  0.900486

# %% [markdown]
# 3. Using boxplots

# %%
boxplot(df, num_cols)

# %% [markdown]
# **Treatment**

# %% [markdown]
# 1. Log Transformation

# %%
df2 = df.copy()

# %%
df2[['log_Dexa','log_Count_Risks']] = np.log1p(df2[['Dexa_Freq_During_Rx','Count_Of_Risks']])

# %%
df2[['log_Dexa','log_Count_Risks']]
# Out:
#       log_Dexa  log_Count_Risks
# 0     0.000000         0.000000
# 1     0.000000         0.000000
# 2     0.000000         1.098612
# 3     0.000000         0.693147
# 4     0.000000         0.693147
# ...        ...              ...
# 3419  0.000000         0.693147
# 3420  0.000000         0.000000
# 3421  2.079442         0.693147
# 3422  0.000000         0.000000
# 3423  0.000000         0.693147
#
# [3424 rows x 2 columns]

# %%
#Checking skew after transformation
df2.agg(['skew', 'kurtosis']).transpose()
# Out:
#                          skew   kurtosis
# Dexa_Freq_During_Rx  6.808730  74.758378
# Count_Of_Risks       0.879791   0.900486
# log_Dexa             1.405860   0.624570
# log_Count_Risks     -0.091583  -1.006414

# %%
df2.hist(grid=False,
       figsize=(10, 6),
       bins=10)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f40be50f3d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f40be726790>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f40be4e7290>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f40be6e6a10>]],
#       dtype=object)

# %% [markdown]
# 2. Recipricol Transformation

# %%
df3 = df.copy()

# %%
df3[['reci_Dexa','reci_Count_Risks']] = np.reciprocal(df3[['Dexa_Freq_During_Rx','Count_Of_Risks']])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in reciprocal
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in reciprocal
#   """Entry point for launching an IPython kernel.

# %%
df3[['reci_Dexa','reci_Count_Risks']]
# Out:
#                 reci_Dexa     reci_Count_Risks
# 0    -9223372036854775808 -9223372036854775808
# 1    -9223372036854775808 -9223372036854775808
# 2    -9223372036854775808                    0
# 3    -9223372036854775808                    1
# 4    -9223372036854775808                    1
# ...                   ...                  ...
# 3419 -9223372036854775808                    1
# 3420 -9223372036854775808 -9223372036854775808
# 3421                    0                    1
# 3422 -9223372036854775808 -9223372036854775808
# 3423 -9223372036854775808                    1
#
# [3424 rows x 2 columns]

# %%
#Checking skew after transformation
df3.agg(['skew', 'kurtosis']).transpose()
# Out:
#                          skew   kurtosis
# Dexa_Freq_During_Rx  6.808730  74.758378
# Count_Of_Risks       0.879791   0.900486
# reci_Dexa            1.017464  -0.965332
# reci_Count_Risks    -0.962279  -1.074647

# %%
df3.hist(grid=False,
       figsize=(10, 6),
       bins=10)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f40bb91c950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f40bb8dded0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f40bb896590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f40bb84ac10>]],
#       dtype=object)

# %% [markdown]
# 3. Min-Max Transformation

# %%
# min-max normalization
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df_min_max = df.copy() #getting a copy of dataframe
for col in num_cols:
    data = np.array(df_min_max[[col]])
    scaler.fit(data)#computing min and max to be used for scaling
    df['min_max_'+col] = scaler.transform(data) 
    measure_skew_kurtosis(['min_max_'+col]) #measure skewness and kurtosis
    plot_histogram(df, ['min_max_'+col]) # plot histogram
# Out:
# min_max_Dexa_Freq_During_Rx
#                                 skew   kurtosis
# min_max_Dexa_Freq_During_Rx  6.80873  74.758378
# min_max_Count_Of_Risks
#                             skew  kurtosis
# min_max_Count_Of_Risks  0.879791  0.900486

# %% [markdown]
# 4. Square root Transformation

# %%
for col in num_cols:
    df['sqrt_'+col] = np.sqrt(df[col])
    measure_skew_kurtosis(['sqrt_'+col]) #measure skewness and kurtosis
    plot_histogram(df, ['sqrt_'+col]) # plot histogram
# Out:
# sqrt_Dexa_Freq_During_Rx
#                               skew  kurtosis
# sqrt_Dexa_Freq_During_Rx  1.992495  4.734647
# sqrt_Count_Of_Risks
#                          skew  kurtosis
# sqrt_Count_Of_Risks -0.327599 -1.038321

# %% [markdown]
# 5 Trimming outliers

# %%
import seaborn as sns
# for Q-Q plots
import scipy.stats as stats
def diagnostic_plots(df, variable):
    # function takes a dataframe (df) and
    # the variable of interest as arguments

    # define figure size
    plt.figure(figsize=(16, 4))

    # histogram
    plt.subplot(1, 3, 1)
    sns.histplot(df[variable], bins=30)
    plt.title('Histogram')

    # Q-Q plot
    plt.subplot(1, 3, 2)
    stats.probplot(df[variable], dist="norm", plot=plt)
    plt.ylabel('RM quantiles')

    # boxplot
    plt.subplot(1, 3, 3)
    sns.boxplot(y=df[variable])
    plt.title('Boxplot')

    plt.show()

# %%
# function to find upper and lower boundaries
# for skewed distributed variables


def find_skewed_boundaries(df, variable, distance):

    # Let's calculate the boundaries outside which sit the outliers
    # for skewed distributions

    # distance passed as an argument, gives us the option to
    # estimate 1.5 times or 3 times the IQR to calculate
    # the boundaries.

    IQR = df[variable].quantile(0.75) - df[variable].quantile(0.25)

    lower_boundary = df[variable].quantile(0.25) - (IQR * distance)
    upper_boundary = df[variable].quantile(0.75) + (IQR * distance)

    return upper_boundary, lower_boundary

# %% [markdown]
# For column Dexa_Freq_During_Rx

# %%
df_trim = df.copy()

# %%
#plotting before transformation
diagnostic_plots(df_trim, 'Dexa_Freq_During_Rx')

# %%
# looking for outliers,
# using the interquantile proximity rule
# IQR * 1.5, the standard metric

# dataset

upper_boundary, lower_boundary = find_skewed_boundaries(df_trim, 'Dexa_Freq_During_Rx', 1.5)
upper_boundary, lower_boundary
# Out:
# (7.5, -4.5)

# %%
# lets look at the number and percentage of outliers
# for LSTAT

print('total umber of patients: {}'.format(len(data)))

print('Patients with Dexa_Freq_During_Rx bigger than 32: {}'.format(
    len(df_trim[df_trim['Dexa_Freq_During_Rx'] > upper_boundary])))
print()
print('%Patients with Dexa_Freq_During_Rx bigger than 32: {}'.format(
    len(df_trim[df_trim['Dexa_Freq_During_Rx'] > upper_boundary])/len(df_trim)))
# Out:
# total umber of patients: 3424
# Patients with Dexa_Freq_During_Rx bigger than 32: 460
#
# %Patients with Dexa_Freq_During_Rx bigger than 32: 0.13434579439252337

# %%
# limits for CRIM

CRIM_upper_limit, CRIM_lower_limit = find_skewed_boundaries(df_trim, 'Dexa_Freq_During_Rx', 1.5)
CRIM_upper_limit, CRIM_lower_limit
# Out:
# (7.5, -4.5)

# %%
# let's flag the outliers in the data set

outliers_CRIM = np.where(df_trim['Dexa_Freq_During_Rx'] > CRIM_upper_limit, True,
                       np.where(df_trim['Dexa_Freq_During_Rx'] < CRIM_lower_limit, True, False))

# %%
# let's trimm the dataset

data_trimmed = df_trim.loc[~(outliers_CRIM), ]

data.shape, data_trimmed.shape
# Out:
# ((3424, 1), (2964, 73))

# %%
#plotting after transformation
diagnostic_plots(data_trimmed, 'Dexa_Freq_During_Rx')

# %% [markdown]
# For column count of risks

# %%
diagnostic_plots(df_trim, 'Count_Of_Risks')

# %%
# looking for outliers,
# using the interquantile proximity rule
# IQR * 1.5, the standard metric

# dataset

upper_boundary, lower_boundary = find_skewed_boundaries(df_trim, 'Count_Of_Risks', 1.5)
upper_boundary, lower_boundary
# Out:
# (5.0, -3.0)

# %%
# lets look at the number and percentage of outliers
# for LSTAT

print('total umber of patients: {}'.format(len(data)))

print('Patients with Count_Of_Risks bigger than 32: {}'.format(
    len(df_trim[df_trim['Count_Of_Risks'] > upper_boundary])))
print()
print('%Patients with Count_Of_Risks bigger than 32: {}'.format(
    len(df_trim[df_trim['Count_Of_Risks'] > upper_boundary])/len(df_trim)))
# Out:
# total umber of patients: 3424
# Patients with Count_Of_Risks bigger than 32: 8
#
# %Patients with Count_Of_Risks bigger than 32: 0.002336448598130841

# %%
# limits for CRIM

CRIM_upper_limit, CRIM_lower_limit = find_skewed_boundaries(df_trim, 'Count_Of_Risks', 1.5)
CRIM_upper_limit, CRIM_lower_limit
# Out:
# (5.0, -3.0)

# %%
# let's flag the outliers in the data set

outliers_CRIM = np.where(df_trim['Count_Of_Risks'] > CRIM_upper_limit, True,
                       np.where(df_trim['Count_Of_Risks'] < CRIM_lower_limit, True, False))

# %%
# let's trimm the dataset

data_trimmed = df_trim.loc[~(outliers_CRIM), ]

data.shape, data_trimmed.shape
# Out:
# ((3424, 1), (3416, 73))

# %%
#plotting after transformation
diagnostic_plots(data_trimmed, 'Count_Of_Risks')

# %% [markdown]
# **Identifying and Treating Class Imbalance**

# %% [markdown]
# **Identifying**

# %%
print(df['Persistency_Flag'].value_counts())
# Out:
# Non-Persistent    2135
# Persistent        1289
# Name: Persistency_Flag, dtype: int64

# %%
#bar graph for value counts for categorical columns
def plot_catcols(x, df):
    df['dummy'] = np.ones(shape = df.shape[0])
    for col in x:
        print(col)
        counts = df[['dummy', col]].groupby([col], as_index = False).count()
        fig, ax = plt.subplots(figsize = (10,4))
        graph = plt.barh(counts[col], counts.dummy) #creating a graph
        plt.xticks(rotation=90)
        plt.title('Counts for ' + col)
        plt.xlabel('count')
        #getting percentages
        total = counts['dummy'].sum()
        percentage = []
        for i in range(counts.shape[0]):
            pct = (counts.dummy[i]/total)*100
            percentage.append(round(pct, 2))
        counts['Percentage'] = percentage
        # plotting the graph with percentages
        i = 0
        for p in graph:
            pct = f'{percentage[i]}%'
            width1, height1 =p.get_width(),p.get_height()
            x1 =p.get_x()+width1
            y1=p.get_y()+height1/2
            ax.annotate(pct,(x1,y1))
            i+=1
        plt.show()
plot_catcols(['Persistency_Flag'], df)
# Out:
# Persistency_Flag

# %% [markdown]
# **Treating by Oversampling minority class**

# %%
# dealing with class imbalance in the target variable
# oversampling the minority class i.e 'Persistent'

from sklearn.utils import resample

# separating minority and majority classes
non_persistent = df[df['Persistency_Flag']=='Non-Persistent']
persistent = df[df['Persistency_Flag']=='Persistent']

# oversampling minority
persistent_upsampled = resample(persistent,
                           replace=True, # sample with replacement
                           n_samples=len(non_persistent), # match number in majority class
                           random_state=27) # reproducible results

# combine majority and upsampled minority
upsampled_df = pd.concat([non_persistent, persistent_upsampled])

# check new class counts
print(upsampled_df['Persistency_Flag'].value_counts())
# plotting graph of upsampled dataset
plot_catcols(['Persistency_Flag'], upsampled_df)
# Out:
# Persistent        2135
# Non-Persistent    2135
# Name: Persistency_Flag, dtype: int64
# Persistency_Flag
